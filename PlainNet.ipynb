# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import datasets

# %%
n = 5

# %%
inputs = keras.Input( shape = ( 32, 32, 3 ), name = 'input' )

output = layers.Conv2D( filters = 16, kernel_size = [ 7, 7 ],
                       padding = 'Same', activation = 'relu' )(inputs)

# block 1
for _ in range( n ):
    output = layers.Conv2D( filters = 16, kernel_size = [ 3, 3 ],
                           padding = 'Same' )(output)
    output = layers.BatchNormalization()(output)
    output = layers.Activation('relu')(output)
    
    output = layers.Conv2D( filters = 16, kernel_size = [ 3, 3 ],
                           padding = 'Same' )(output)
    output = layers.BatchNormalization()(output)
    output = layers.Activation('relu')(output)

output = layers.MaxPooling2D( pool_size = [ 3, 3 ], padding = 'same',
                               strides = 2 )(output)

# %%
# block 2
output = layers.ZeroPadding2D( [ 0, 8 ], 'channels_first' )(output)
for _ in range( n ):
    output = layers.Conv2D( filters = 32, kernel_size = [ 3, 3 ],
                           padding = 'Same' )(output)
    output = layers.BatchNormalization()(output)
    output = layers.Activation('relu')(output)
    
    output = layers.Conv2D( filters = 32, kernel_size = [ 3, 3 ],
                           padding = 'Same' )(output)
    output = layers.BatchNormalization()(output)
    output = layers.Activation('relu')(output)

output = layers.MaxPooling2D( pool_size = [ 3, 3 ], padding = 'same',
                               strides = 2 )(output)

# %%
# block 3
output = layers.ZeroPadding2D( [ 0, 16 ], 'channels_first' )(output)
for _ in range( n ):
    output = layers.Conv2D( filters = 64, kernel_size = [ 3, 3 ],
                           padding = 'Same' )(output)
    output = layers.BatchNormalization()(output)
    output = layers.Activation('relu')(output)
    
    output = layers.Conv2D( filters = 64, kernel_size = [ 3, 3 ],
                           padding = 'Same' )(output)
    output = layers.BatchNormalization()(output)
    output = layers.Activation('relu')(output)

output = layers.MaxPooling2D( pool_size = [ 3, 3 ], padding = 'same',
                               strides = 2 )(output)

# %%
output = layers.GlobalAveragePooling2D()(output)
output = layers.Dense( 128, activation = 'relu' )(output)
output = layers.Dense( 128, activation = 'relu' )(output)
output = layers.Dense( 10, activation = 'softmax' )(output)

# %%
model = keras.Model( inputs = inputs, outputs = output, name = 'resnet' )
model.summary()
# Out:
# Model: "resnet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 16)        2368
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 16)        64
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_8 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_9 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_10 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_11 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_13 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_15 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_17 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_19 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_21 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_22 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_23 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_24 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_25 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_26 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_27 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_28 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_29 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 517,930
# Trainable params: 515,690
# Non-trainable params: 2,240
# _________________________________________________________________

# %%
lr = 1e-3
BATCH_SIZE = 512
EPOCHS = 25

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = keras.utils.to_categorical( y_train, 10 )
y_test = keras.utils.to_categorical( y_test, 10 )

model.compile( optimizer = keras.optimizers.RMSprop( lr, 0.9 ),
             loss = keras.losses.CategoricalCrossentropy( from_logits = True ),
              metrics = ['acc'])

# %%
history = model.fit( x_train, y_train, batch_size = BATCH_SIZE,
                    epochs = EPOCHS, validation_split = 0.2 )
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/25
# 40000/40000 [==============================] - 15s 387us/sample - loss: 2.2056 - acc: 0.2342 - val_loss: 2.3261 - val_acc: 0.0980
# Epoch 2/25
# 40000/40000 [==============================] - 10s 248us/sample - loss: 2.1399 - acc: 0.3117 - val_loss: 2.2442 - val_acc: 0.2055
# Epoch 3/25
# 40000/40000 [==============================] - 10s 248us/sample - loss: 2.1134 - acc: 0.3396 - val_loss: 2.2748 - val_acc: 0.1842
# Epoch 4/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 2.0984 - acc: 0.3554 - val_loss: 2.2636 - val_acc: 0.1945
# Epoch 5/25
# 40000/40000 [==============================] - 10s 248us/sample - loss: 2.0849 - acc: 0.3690 - val_loss: 2.1944 - val_acc: 0.2632
# Epoch 6/25
# 40000/40000 [==============================] - 10s 249us/sample - loss: 2.0690 - acc: 0.3859 - val_loss: 2.3557 - val_acc: 0.1035
# Epoch 7/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 2.0562 - acc: 0.3979 - val_loss: 2.2970 - val_acc: 0.1586
# Epoch 8/25
# 40000/40000 [==============================] - 10s 249us/sample - loss: 2.0385 - acc: 0.4169 - val_loss: 2.2943 - val_acc: 0.1638
# Epoch 9/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 2.0331 - acc: 0.4207 - val_loss: 2.2189 - val_acc: 0.2319
# Epoch 10/25
# 40000/40000 [==============================] - 10s 255us/sample - loss: 2.0190 - acc: 0.4370 - val_loss: 2.1168 - val_acc: 0.3380
# Epoch 11/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 2.0063 - acc: 0.4491 - val_loss: 2.0792 - val_acc: 0.3763
# Epoch 12/25
# 40000/40000 [==============================] - 10s 249us/sample - loss: 1.9995 - acc: 0.4559 - val_loss: 2.2446 - val_acc: 0.2136
# Epoch 13/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 1.9937 - acc: 0.4620 - val_loss: 2.1643 - val_acc: 0.2905
# Epoch 14/25
# 40000/40000 [==============================] - 10s 253us/sample - loss: 1.9828 - acc: 0.4740 - val_loss: 2.1890 - val_acc: 0.2630
# Epoch 15/25
# 40000/40000 [==============================] - 10s 253us/sample - loss: 1.9769 - acc: 0.4793 - val_loss: 2.2140 - val_acc: 0.2427
# Epoch 16/25
# 40000/40000 [==============================] - 10s 253us/sample - loss: 1.9687 - acc: 0.4887 - val_loss: 2.1116 - val_acc: 0.3445
# Epoch 17/25
# 40000/40000 [==============================] - 10s 252us/sample - loss: 1.9600 - acc: 0.4968 - val_loss: 2.2050 - val_acc: 0.2513
# Epoch 18/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 1.9592 - acc: 0.4983 - val_loss: 2.1079 - val_acc: 0.3473
# Epoch 19/25
# 40000/40000 [==============================] - 10s 249us/sample - loss: 1.9512 - acc: 0.5052 - val_loss: 2.0797 - val_acc: 0.3743
# Epoch 20/25
# 40000/40000 [==============================] - 10s 252us/sample - loss: 1.9412 - acc: 0.5165 - val_loss: 2.0996 - val_acc: 0.3568
# Epoch 21/25
# 40000/40000 [==============================] - 11s 263us/sample - loss: 1.9325 - acc: 0.5261 - val_loss: 2.1615 - val_acc: 0.2974
# Epoch 22/25
# 40000/40000 [==============================] - 10s 260us/sample - loss: 1.9269 - acc: 0.5303 - val_loss: 2.0471 - val_acc: 0.4100
# Epoch 23/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 1.9149 - acc: 0.5428 - val_loss: 1.9960 - val_acc: 0.4618
# Epoch 24/25
# 40000/40000 [==============================] - 10s 252us/sample - loss: 1.9133 - acc: 0.5440 - val_loss: 2.0041 - val_acc: 0.4542
# Epoch 25/25
# 40000/40000 [==============================] - 10s 250us/sample - loss: 1.9050 - acc: 0.5528 - val_loss: 2.0409 - val_acc: 0.4169

# %%
evaluation = model.evaluate( x_test, y_test )
print( f'loss: {evaluation[0]:.2f}, acc: {evaluation[1]*100:.2f}%' )
# Out:
# 10000/10000 [==============================] - 2s 177us/sample - loss: 2.0349 - acc: 0.4220
# loss: 2.03, acc: 42.20%

# %%
# model.save('resnet_RMS_lr1e3_epoch25.h5')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot( history.history['acc'] )
plt.plot( history.history['val_acc'])
plt.xlabel( 'epochs' )
plt.ylabel( 'acc' )
plt.legend( ['acc', 'val_acc'] )

plt.savefig('plain.png')
plt.show()
